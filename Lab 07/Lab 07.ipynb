# %% [markdown]
# Lab 07:
# My Menu Driven Restaurant
#
# In the charming little town named "Culinary Haven", there stood a restaurant called "The Enchanted Fork". This restaurant was more than just a place to eat; it was a magical experience that left a lasting impression on all who visited. The restaurant is also famous for its management application that takes up customer orders.
#
# The software collects the order details for the customers. The application generates a unique orderid for each order based on the below specifications. The software system has a predefined menu of items and their prices, from which the user can select them.
#
# OrderID is created with the help of a combination of 5 random numbers generated with the help of a random library in Python. You can use random.randint() function to get one random integer at a time and the order id is generated by concatenating five such numbers.
#
# Apart from orderid, each order will have the items ordered and their quantity saved.
#
# The application has the following options in its menu:
#
# Create new order
# View Orders (List and calculate the bill for each order)
# Assumptions:
# Each order will have a unique orderID generated as per the specifications given.
# Each order can have multiple items.
# Once the order is completed, you may calculate the total order value
# You can set a predefined menu and price for the items
# Expectations:
# Identify the appropriate data storage mechanisms to store the order data effectively.
# Usage of functions
# menu items stored in the format: [["Rice",30],["Tea",10],.....]
# Each order needs to be saved in the following format
# {
# "Orderid": 56837,
# "items": [
# {
# "itemnumber": 2,
# "quantity": 1,
# },
# {
# "itemnumber": 1,
# "quantity": 1,
# },
# ]
# }
#
# Additional Task (Optional):
# Save the order details to the file

# %%
import random#importing random function
menu=[["coffi",10],["chaya",20],["apple",30],["banana",40],["rice",50]]
print(menu)

# %% [markdown]
# defining function to make random id

# %%
def order_id():
    orderid=''.join(str(random.randint(0,9))for i in range(5))
    return int(orderid)
order_id()

# %% [markdown]
# defing function to add new order

# %%
menu=[["coffi",10],["chaya",20],["apple",30],["banana",40],["rice",50]]
total_prize=0
def printMenu():
    count = 1;
    for item in menu:
        print(count,item[0],item[1])
        count += 1
printMenu()        


def order_iteam(menu):
 
  #total_prize=0 
 
 while True:
   printMenu()   
   choice=int(input("enter your choice"))
   for iteam in menu:
    if iteam==choice:
      qty=int(input("enter the quantity"))
      prize=menu[choice][1]*qty
      total_prize+=prize
#return menu[choice][1]
#return menu[choice][0]
#return qty

#order_iteam()
   
#def order_view(qty,menu[choice][0],menu[choice][1],choice):     
      print("your order :",menu[choice][0],"   ","prize :",menu[choice][1],"   ","quantity :",qty,)


#order_view(qty,menu[choice][0],menu[choice][1],choice)     
     
    if choice==5:
      print("\ntoatal prize :",total_prize)
      print("thank you.....!") 
    break
order_iteam(menu)
# Out:
# 1 coffi 10
# 2 chaya 20
# 3 apple 30
# 4 banana 40
# 5 rice 50
# 1 coffi 10
# 2 chaya 20
# 3 apple 30
# 4 banana 40
# 5 rice 50
# 1 coffi 10
# 2 chaya 20
# 3 apple 30
# 4 banana 40
# 5 rice 50
# 1 coffi 10
# 2 chaya 20
# 3 apple 30
# 4 banana 40
# 5 rice 50
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# d:\github\MScDSA-MDS171-23122016-JAISE\Lab 07\Lab 07.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a>       print("thank you.....!")
#      <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=37'>38</a>     break
# ---> <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=38'>39</a> order_iteam(menu)
#
# d:\github\MScDSA-MDS171-23122016-JAISE\Lab 07\Lab 07.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=32'>33</a> #order_view(qty,menu[choice][0],menu[choice][1],choice)
#      <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=34'>35</a>     if choice==5:
# ---> <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=35'>36</a>       print("\ntoatal prize :",total_prize)
#      <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a>       print("thank you.....!")
#      <a href='vscode-notebook-cell:/d%3A/github/MScDSA-MDS171-23122016-JAISE/Lab%2007/Lab%2007.ipynb#X10sZmlsZQ%3D%3D?line=37'>38</a>     break
#
# UnboundLocalError: cannot access local variable 'total_prize' where it is not associated with a value

# %%
    


def order_iteam():
 total_prize=0
 
 
 while True:
  choice=int(input("enter your choice"))
  for iteam in cho:
    if iteam==choice:
      qty=int(input("enter the quantity"))
      prize=menu[choice][1]*qty
      total_prize+=prize
#return menu[choice][1]
#return menu[choice][0]
#return qty

#order_iteam()
   
#def order_view(qty,menu[choice][0],menu[choice][1],choice):     
      print("your order :",menu[choice][0],"   ","prize :",menu[choice][1],"   ","quantity :",qty,)


#order_view(qty,menu[choice][0],menu[choice][1],choice)     
     
    if choice==5:
      print("\ntoatal prize :",total_prize)
      print("thank you.....!") 
      break
    
order_iteam()

# %%
    
print("\nM_E_N_U:")
print("1.new order")
print("2.view order")
print("3.exit....!")
option=int(input("Enter your choice...!"))
if option==1:
        order_iteam()
elif option==2:
        view_order()

else:
    print("enter a valid choice...!")
