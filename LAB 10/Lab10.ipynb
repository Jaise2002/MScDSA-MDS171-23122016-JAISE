# %% [markdown]
# LAB:10
# Create a Python Class for managing student details and marks.
# Define the class and implement the methods of the student class in a menu-driven program for different types of users

# %%
class StudentManagement():#creating a class
    def _init_(self):
        self.file = ""
        
    def open(self):#defining a function which will show student detils
        x= file.readlines()
        for i in x:
          print("\t",i)

    def searching(self,name):#function to search student detil
        x= file.readlines()
        for i in x:
            k = i.strip().split(",")            
            if name in k:
               print("exist")
               print(k)
    def update(self,StudentID,Name,Math,Science,History):#function to update student detilc
        file.write(StudentID+",")
        file.write(Name+",")
        file.write(Math+",")
        file.write(Science+",")
        file.write(History+"\n")

    
SM =StudentManagement()
while True:
    print("*"*20,"MENU","*"*20)
    print("1.SEARCH A STUDENT")
    print('2.UPDATE THE STUDENT DATA')
    print("3.SEE STUDENT DETIL")
    print("4.EXIT...!")
    ch = int(input("enter choice:"))

    if ch == 1:
        name=input("id")
        file=open("STUDENT DETAILS.csv","r")
        SM.searching(name)
    if ch == 2:
        file=open("STUDENT DETAILS.csv","a")
        id=input("id")
        Name=input("name")
       
        Math=input("maths")
        Science=input("science")
        History=input("history")
        SM.update(id,Name,Math,Science,History,)
    if ch == 4:
        break
    if ch == 3:
        file=open("STUDENT DETAILS.csv","r")
        SM.open()
# Out:
# ******************** MENU ********************
# 1.SEARCH A STUDENT
# 2.UPDATE THE STUDENT DATA
# 3.SEE STUDENT DETIL
# 4.EXIT...!
# 	 StudentID,Name,Math,Science,History
#
# 	 1,Alice,90,88,78
#
# 	 2,Bob,85,91,80
#
# 	 3,Charlie,92,89,85
#
# 	 4,David,95,87,91
#
# 	 5,Emily,88,90,87
#
# 	 6,Frank,89,86,82
#
# 	 7,Grace,91,94,89
#
# 	 8,Henry,87,92,86
#
# 	 9,Isabella,94,88,90
#
# 	 10,Jack,88,85,89
#
#
#
# ******************** MENU ********************
# 1.SEARCH A STUDENT
# 2.UPDATE THE STUDENT DATA
# 3.SEE STUDENT DETIL
# 4.EXIT...!
# ******************** MENU ********************
# 1.SEARCH A STUDENT
# 2.UPDATE THE STUDENT DATA
# 3.SEE STUDENT DETIL
# 4.EXIT...!
# exist
# ['10', 'Jack', '88', '85', '89']
# ******************** MENU ********************
# 1.SEARCH A STUDENT
# 2.UPDATE THE STUDENT DATA
# 3.SEE STUDENT DETIL
# 4.EXIT...!
# exist
# ['11', 'jaise george', '50', '60', '70']
# ******************** MENU ********************
# 1.SEARCH A STUDENT
# 2.UPDATE THE STUDENT DATA
# 3.SEE STUDENT DETIL
# 4.EXIT...!
# 	 StudentID,Name,Math,Science,History
#
# 	 1,Alice,90,88,78
#
# 	 2,Bob,85,91,80
#
# 	 3,Charlie,92,89,85
#
# 	 4,David,95,87,91
#
# 	 5,Emily,88,90,87
#
# 	 6,Frank,89,86,82
#
# 	 7,Grace,91,94,89
#
# 	 8,Henry,87,92,86
#
# 	 9,Isabella,94,88,90
#
# 	 10,Jack,88,85,89
#
#
#
# 	 11,jaise george,50,60,70
#
# ******************** MENU ********************
# 1.SEARCH A STUDENT
# 2.UPDATE THE STUDENT DATA
# 3.SEE STUDENT DETIL
# 4.EXIT...!
# 	 StudentID,Name,Math,Science,History
#
# 	 1,Alice,90,88,78
#
# 	 2,Bob,85,91,80
#
# 	 3,Charlie,92,89,85
#
# 	 4,David,95,87,91
#
# 	 5,Emily,88,90,87
#
# 	 6,Frank,89,86,82
#
# 	 7,Grace,91,94,89
#
# 	 8,Henry,87,92,86
#
# 	 9,Isabella,94,88,90
#
# 	 10,Jack,88,85,89
#
#
#
# 	 11,jaise george,50,60,70
#
# ******************** MENU ********************
# 1.SEARCH A STUDENT
# 2.UPDATE THE STUDENT DATA
# 3.SEE STUDENT DETIL
# 4.EXIT...!
